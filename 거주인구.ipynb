# %%
import pandas as pd

# %%
df=pd.read_csv('/Users/minjikim/Downloads/report.txt',sep = "\t")

df.head()
# Out:
#          기간  자치구    동      세대 계(Total) 남자(Total) 여자(Total)   계(한국인) 남자(한국인)  \
# 0  2021.2/4  종로구   소계  73,525  155,106    75,009    80,097  146,029  70,985
# 1  2021.2/4  종로구  사직동   4,674    9,636     4,380     5,256    9,371   4,225
# 2  2021.2/4  종로구  삼청동   1,248    2,780     1,328     1,452    2,498   1,191
# 3  2021.2/4  종로구  부암동   4,286    9,951     4,775     5,176    9,703   4,639
# 4  2021.2/4  종로구  평창동   7,482   18,377     8,558     9,819   18,204   8,478
#
#   여자(한국인) 계(외국인) 남자(외국인) 여자(외국인)  세대당인구 65세이상고령자
# 0  75,044  9,077   4,024   5,053   1.99   27,605
# 1   5,146    265     155     110   2.00    1,761
# 2   1,307    282     137     145   2.00      632
# 3   5,064    248     136     112   2.26    1,775
# 4   9,726    173      80      93   2.43    3,385

# %%
df['동']=df[df['동']!='소계']

df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/zr/zcxyh13d1qj0cly9bgl4gbw80000gn/T/ipykernel_28768/558156446.py in <module>
# ----> 1 df['동']=df[df['동']!='소계']
#       2
#       3 df.head()
#
# /usr/local/Cellar/jupyterlab/3.1.10/libexec/lib/python3.9/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3600             self._setitem_array(key, value)
#    3601         elif isinstance(value, DataFrame):
# -> 3602             self._set_item_frame_value(key, value)
#    3603         elif (
#    3604             is_list_like(value)
#
# /usr/local/Cellar/jupyterlab/3.1.10/libexec/lib/python3.9/site-packages/pandas/core/frame.py in _set_item_frame_value(self, key, value)
#    3727             len_cols = 1 if is_scalar(cols) else len(cols)
#    3728             if len_cols != len(value.columns):
# ...
